# %% [markdown]
# Вариант 4
# (Методы):
# 1)замена критериев ограничениями;
# 2)взвешивание и объединение критериев;
# 3)формирование и сужение множества Парето;
# 4)анализ иерархий

# %% [markdown]
# Входные данные

# %%
from plotly.graph_objects import Figure, Table
from plotly.offline import iplot
import numpy as np


# Альтернативы
alternatives = ['Автострада', 'Шоссе', 'Грунтовка', 'Проселок']

# Критерии
criterions = ['Расстояние',
              'Качество покрытия',
              'Контроль',
              'Инфраструктура']

# Для матрицы оценок результатов
distanс = [2.,3.,6.,7.] # Чем больше расстояние, тем меньше оценка
quality = [8.,6.,2.,1.]
control = [1.,2.,5.,6.] # Чем больше контроль, тем меньше оценка
infrast = [7.,8.,3.,1.]


# Веса критериев
weights = [6.,8.,2.,4.]
# Нормализация списка весов критериев
weights = [w / 10 for w in weights]

# Матрица оценок для альтернатив
a_matrix = np.array([distanс,
            quality,
            control,
            infrast], dtype=float)
print(a_matrix)

# Вывод изначальной таблицы оценок
fig_beg = Figure(data=[
    Table(
        header=dict(values=['Альтернативы\Критерии'] + criterions),
        cells=dict(
            values=[
                alternatives,
                distanс,
                quality,
                control,
                infrast
            ]),
    )])
iplot(fig_beg)

# Точность после запятой
okr = 5

# # Нормировка матрицы оценок (все столбцы)
# # Цикл по столбикам (критериям)
# for j, cr in enumerate(criterions):
#
#     min_val = min(a_matrix[j])
#     max_val = max(a_matrix[j])
#
#     # Цикл по строчкам (значения критериев альтернатив)
#     for i, al in enumerate(alternatives):
#         a_matrix[j][i] = round((a_matrix[j][i] - min_val) / (max_val - min_val), okr)
#
# # Вывод нормализованной таблицы
# fig_norm = Figure(data=[
#     Table(
#         header=dict(values=['Альтернативы\Критерии'] + criterions),
#         cells=dict(
#             values=[
#                 alternatives,
#                 a_matrix[0],
#                 a_matrix[1],
#                 a_matrix[2],
#                 a_matrix[3]
#             ]),
#     )])
# iplot(fig_norm)
# Out:
# [[2. 3. 6. 7.]
#  [8. 6. 2. 1.]
#  [1. 2. 5. 6.]
#  [7. 8. 3. 1.]]
# <div>                            <div id="97d0d29f-04fa-447a-bfc3-b508b4cb4bdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97d0d29f-04fa-447a-bfc3-b508b4cb4bdd")) {                    Plotly.newPlot(                        "97d0d29f-04fa-447a-bfc3-b508b4cb4bdd",                        [{"cells":{"values":[["\u0410\u0432\u0442\u043e\u0441\u0442\u0440\u0430\u0434\u0430","\u0428\u043e\u0441\u0441\u0435","\u0413\u0440\u0443\u043d\u0442\u043e\u0432\u043a\u0430","\u041f\u0440\u043e\u0441\u0435\u043b\u043e\u043a"],[2.0,3.0,6.0,7.0],[8.0,6.0,2.0,1.0],[1.0,2.0,5.0,6.0],[7.0,8.0,3.0,1.0]]},"header":{"values":["\u0410\u043b\u044c\u0442\u0435\u0440\u043d\u0430\u0442\u0438\u0432\u044b\\\u041a\u0440\u0438\u0442\u0435\u0440\u0438\u0438","\u0420\u0430\u0441\u0441\u0442\u043e\u044f\u043d\u0438\u0435","\u041a\u0430\u0447\u0435\u0441\u0442\u0432\u043e \u043f\u043e\u043a\u0440\u044b\u0442\u0438\u044f","\u041a\u043e\u043d\u0442\u0440\u043e\u043b\u044c","\u0418\u043d\u0444\u0440\u0430\u0441\u0442\u0440\u0443\u043a\u0442\u0443\u0440\u0430"]},"type":"table"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777777777 ...

# %% [markdown]
# Метод замены критериев ограничениями

# %%
# Пусть главный критерий - Расстояние

# Нормировка матриц оценок (кроме столбца главного критерия)
# Цикл по столбикам (критериям)
for j, cr in enumerate(criterions):
    # Если это главный критерий, то пропустить
    if cr == 'Расстояние':
        continue

    lev = None
    # Минимально допустимые уровни для остальных критериев
    match(cr):
        case 'Качество покрытия':
            lev = 0.3
        case 'Контроль':
            lev = 0.1
        case 'Инфраструктура':
            lev = 0.2

    min_val = min(a_matrix[j])
    max_val = max(a_matrix[j])

    # Цикл по строчкам (значения критериев альтернатив)
    for i, al in enumerate(alternatives):
        a_matrix[j][i] = round((a_matrix[j][i] - min_val) / (max_val - min_val), okr)
        # Оставить только приемлемые значения
        if a_matrix[j][i] < lev:
            a_matrix[j][i] = 0.0

# Вывод таблицы
fig = Figure(data=[
    Table(
        header=dict(values=['Альтернативы\Критерии'] + criterions),
        cells=dict(
            values=[
                alternatives,
                a_matrix[0],
                a_matrix[1],
                a_matrix[2],
                a_matrix[3]
            ]),
    )])
iplot(fig)
# Out:
# <div>                            <div id="2f61da10-f7c1-410a-b59e-956c9d72c947" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f61da10-f7c1-410a-b59e-956c9d72c947")) {                    Plotly.newPlot(                        "2f61da10-f7c1-410a-b59e-956c9d72c947",                        [{"cells":{"values":[["\u0410\u0432\u0442\u043e\u0441\u0442\u0440\u0430\u0434\u0430","\u0428\u043e\u0441\u0441\u0435","\u0413\u0440\u0443\u043d\u0442\u043e\u0432\u043a\u0430","\u041f\u0440\u043e\u0441\u0435\u043b\u043e\u043a"],[2.0,3.0,6.0,7.0],[1.0,0.71429,0.0,0.0],[0.0,0.2,0.8,1.0],[0.85714,1.0,0.28571,0.0]]},"header":{"values":["\u0410\u043b\u044c\u0442\u0435\u0440\u043d\u0430\u0442\u0438\u0432\u044b\\\u041a\u0440\u0438\u0442\u0435\u0440\u0438\u0438","\u0420\u0430\u0441\u0441\u0442\u043e\u044f\u043d\u0438\u0435","\u041a\u0430\u0447\u0435\u0441\u0442\u0432\u043e \u043f\u043e\u043a\u0440\u044b\u0442\u0438\u044f","\u041a\u043e\u043d\u0442\u0440\u043e\u043b\u044c","\u0418\u043d\u0444\u0440\u0430\u0441\u0442\u0440\u0443\u043a\u0442\u0443\u0440\u0430"]},"type":"table"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777 ...
